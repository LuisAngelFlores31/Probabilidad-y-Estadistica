# %% [markdown]
# <a href="https://colab.research.google.com/github/LuisAngelFlores31/Probabilidad-y-Estadistica/blob/main/Unidad%201/Pr%C3%A1ctica_4_y_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Unidad 1
#
# ##Practica 4. Tablas de Frecuencias
#
# ###Facilitador: Dr. José Gabriel Rodríguez Rivas
#
# ###Alumno: Luis Angel Flores Salazar

# %%
import random
edades = []
for i in range(100):
  numero_aleatorio = random.randint(18, 70)
  edades.append(numero_aleatorio)
print(edades)
# Out:
# [23, 32, 57, 23, 59, 45, 69, 38, 20, 31, 29, 36, 34, 42, 45, 63, 24, 67, 28, 32, 33, 52, 28, 39, 37, 67, 25, 43, 43, 39, 29, 34, 47, 67, 35, 63, 56, 47, 55, 64, 52, 26, 37, 24, 59, 18, 34, 69, 34, 30, 41, 44, 55, 39, 54, 48, 21, 36, 31, 39, 55, 64, 58, 60, 23, 47, 66, 24, 51, 20, 20, 70, 46, 69, 41, 68, 26, 45, 39, 60, 68, 63, 43, 50, 44, 60, 30, 65, 52, 59, 63, 26, 64, 58, 30, 33, 62, 62, 36, 42]

# %%
import pandas as pd

# %%
df = pd.DataFrame(edades,columns=['Edad'])
df.head()
# Out:
#    Edad
# 0    23
# 1    32
# 2    57
# 3    23
# 4    59

# %%
tabla_frecuencias = df['Edad'].value_counts().reset_index()
tabla_frecuencias.columns = ['Edad', 'Frecuencia']
tabla_frecuencias = tabla_frecuencias.sort_values (by='Edad')
tabla_frecuencias
# Out:
#     Edad  Frecuencia
# 42    18           1
# 18    20           3
# 45    21           1
# 3     23           3
# 12    24           3
# 43    25           1
# 6     26           3
# 26    28           2
# 29    29           2
# 5     30           3
# 28    31           2
# 25    32           2
# 30    33           2
# 2     34           4
# 37    35           1
# 16    36           3
# 27    37           2
# 44    38           1
# 0     39           5
# 22    41           2
# 23    42           2
# 9     43           3
# 21    44           2
# 17    45           3
# 34    46           1
# 13    47           3
# 40    48           1
# 33    50           1
# 36    51           1
# 10    52           3
# 41    54           1
# 8     55           3
# 39    56           1
# 38    57           1
# 20    58           2
# 14    59           3
# 4     60           3
# 24    62           2
# 1     63           4
# 7     64           3
# 32    65           1
# 31    66           1
# 11    67           3
# 19    68           2
# 15    69           3
# 35    70           1

# %%
tabla_frecuencias['Frec Relativa'] = tabla_frecuencias['Frecuencia'] /100
tabla_frecuencias
# Out:
#     Edad  Frecuencia  Frec Relativa
# 42    18           1           0.01
# 18    20           3           0.03
# 45    21           1           0.01
# 3     23           3           0.03
# 12    24           3           0.03
# 43    25           1           0.01
# 6     26           3           0.03
# 26    28           2           0.02
# 29    29           2           0.02
# 5     30           3           0.03
# 28    31           2           0.02
# 25    32           2           0.02
# 30    33           2           0.02
# 2     34           4           0.04
# 37    35           1           0.01
# 16    36           3           0.03
# 27    37           2           0.02
# 44    38           1           0.01
# 0     39           5           0.05
# 22    41           2           0.02
# 23    42           2           0.02
# 9     43           3           0.03
# 21    44           2           0.02
# 17    45           3           0.03
# 34    46           1           0.01
# 13    47           3           0.03
# 40    48           1           0.01
# 33    50           1           0.01
# 36    51           1           0.01
# 10    52           3           0.03
# 41    54           1           0.01
# 8     55           3           0.03
# 39    56           1           0.01
# 38    57           1           0.01
# 20    58           2           0.02
# 14    59           3           0.03
# 4     60           3           0.03
# 24    62           2           0.02
# 1     63           4           0.04
# 7     64           3           0.03
# 32    65           1           0.01
# 31    66           1           0.01
# 11    67           3           0.03
# 19    68           2           0.02
# 15    69           3           0.03
# 35    70           1           0.01

# %%
tabla_frecuencias['Frec Porcentual'] = tabla_frecuencias['Frecuencia'] /100 * 100
tabla_frecuencias
# Out:
#     Edad  Frecuencia  Frec Relativa  Frec Porcentual
# 42    18           1           0.01              1.0
# 18    20           3           0.03              3.0
# 45    21           1           0.01              1.0
# 3     23           3           0.03              3.0
# 12    24           3           0.03              3.0
# 43    25           1           0.01              1.0
# 6     26           3           0.03              3.0
# 26    28           2           0.02              2.0
# 29    29           2           0.02              2.0
# 5     30           3           0.03              3.0
# 28    31           2           0.02              2.0
# 25    32           2           0.02              2.0
# 30    33           2           0.02              2.0
# 2     34           4           0.04              4.0
# 37    35           1           0.01              1.0
# 16    36           3           0.03              3.0
# 27    37           2           0.02              2.0
# 44    38           1           0.01              1.0
# 0     39           5           0.05              5.0
# 22    41           2           0.02              2.0
# 23    42           2           0.02              2.0
# 9     43           3           0.03              3.0
# 21    44           2           0.02              2.0
# 17    45           3           0.03              3.0
# 34    46           1           0.01              1.0
# 13    47           3           0.03              3.0
# 40    48           1           0.01              1.0
# 33    50           1           0.01              1.0
# 36    51           1           0.01              1.0
# 10    52           3           0.03              3.0
# 41    54           1           0.01              1.0
# 8     55           3           0.03              3.0
# 39    56           1           0.01              1.0
# 38    57           1           0.01              1.0
# 20    58           2           0.02              2.0
# 14    59           3           0.03              3.0
# 4     60           3           0.03              3.0
# 24    62           2           0.02              2.0
# 1     63           4           0.04              4.0
# 7     64           3           0.03              3.0
# 32    65           1           0.01              1.0
# 31    66           1           0.01              1.0
# 11    67           3           0.03              3.0
# 19    68           2           0.02              2.0
# 15    69           3           0.03              3.0
# 35    70           1           0.01              1.0

# %%
tabla_frecuencias['Frec acumulada'] = tabla_frecuencias['Frecuencia'].cumsum()
tabla_frecuencias
# Out:
#     Edad  Frecuencia  Frec Relativa  Frec Porcentual  Frec acumulada
# 42    18           1           0.01              1.0               1
# 18    20           3           0.03              3.0               4
# 45    21           1           0.01              1.0               5
# 3     23           3           0.03              3.0               8
# 12    24           3           0.03              3.0              11
# 43    25           1           0.01              1.0              12
# 6     26           3           0.03              3.0              15
# 26    28           2           0.02              2.0              17
# 29    29           2           0.02              2.0              19
# 5     30           3           0.03              3.0              22
# 28    31           2           0.02              2.0              24
# 25    32           2           0.02              2.0              26
# 30    33           2           0.02              2.0              28
# 2     34           4           0.04              4.0              32
# 37    35           1           0.01              1.0              33
# 16    36           3           0.03              3.0              36
# 27    37           2           0.02              2.0              38
# 44    38           1           0.01              1.0              39
# 0     39           5           0.05              5.0              44
# 22    41           2           0.02              2.0              46
# 23    42           2           0.02              2.0              48
# 9     43           3           0.03              3.0              51
# 21    44           2           0.02              2.0              53
# 17    45           3           0.03              3.0              56
# 34    46           1           0.01              1.0              57
# 13    47           3           0.03              3.0              60
# 40    48           1           0.01              1.0              61
# 33    50           1           0.01              1.0              62
# 36    51           1           0.01              1.0              63
# 10    52           3           0.03              3.0              66
# 41    54           1           0.01              1.0              67
# 8     55           3           0.03              3.0              70
# 39    56           1           0.01              1.0              71
# 38    57           1           0.01              1.0              72
# 20    58           2           0.02              2.0              74
# 14    59           3           0.03              3.0              77
# 4     60           3           0.03              3.0              80
# 24    62           2           0.02              2.0              82
# 1     63           4           0.04              4.0              86
# 7     64           3           0.03              3.0              89
# 32    65           1           0.01              1.0              90
# 31    66           1           0.01              1.0              91
# 11    67           3           0.03              3.0              94
# 19    68           2           0.02              2.0              96
# 15    69           3           0.03              3.0              99
# 35    70           1           0.01              1.0             100

# %%
import math

# %%
print(edades)
# Out:
# [23, 32, 57, 23, 59, 45, 69, 38, 20, 31, 29, 36, 34, 42, 45, 63, 24, 67, 28, 32, 33, 52, 28, 39, 37, 67, 25, 43, 43, 39, 29, 34, 47, 67, 35, 63, 56, 47, 55, 64, 52, 26, 37, 24, 59, 18, 34, 69, 34, 30, 41, 44, 55, 39, 54, 48, 21, 36, 31, 39, 55, 64, 58, 60, 23, 47, 66, 24, 51, 20, 20, 70, 46, 69, 41, 68, 26, 45, 39, 60, 68, 63, 43, 50, 44, 60, 30, 65, 52, 59, 63, 26, 64, 58, 30, 33, 62, 62, 36, 42]

# %%
df = pd.DataFrame({'Edad': edades})
df
# Out:
#     Edad
# 0     23
# 1     32
# 2     57
# 3     23
# 4     59
# ..   ...
# 95    33
# 96    62
# 97    62
# 98    36
# 99    42
#
# [100 rows x 1 columns]

# %%
n = len(edades)
K = int(1+ math.log2(n))
print("Valor de n =", n, "\nNúmero de intervalos =", K)
# Out:
# Valor de n = 100
# Número de intervalos = 7

# %%
tabla_frecuencia = pd.cut(df['Edad'], bins=K, include_lowest=True).value_counts().reset_index()
tabla_frecuencia.columns = ['Clase', 'Frec']
tabla_frecuencia
# Out:
#               Clase  Frec
# 0  (32.857, 40.286]    18
# 1    (62.571, 70.0]    18
# 2  (40.286, 47.714]    16
# 3  (25.429, 32.857]    14
# 4  (17.947, 25.429]    12
# 5  (55.143, 62.571]    12
# 6  (47.714, 55.143]    10

# %%
tabla_frecuencia = tabla_frecuencia.sort_values(by='Clase')
tabla_frecuencia
# Out:
#               Clase  Frec
# 4  (17.947, 25.429]    12
# 3  (25.429, 32.857]    14
# 0  (32.857, 40.286]    18
# 2  (40.286, 47.714]    16
# 6  (47.714, 55.143]    10
# 5  (55.143, 62.571]    12
# 1    (62.571, 70.0]    18

# %%
tabla_frecuencia['Frec Rel'] = tabla_frecuencia['Frec'] / n
tabla_frecuencia['Frec Porc'] = tabla_frecuencia['Frec'] / n * 100
tabla_frecuencia['Frec Ac'] = tabla_frecuencia['Frec'].cumsum()
tabla_frecuencia['Frec Rel Ac'] = tabla_frecuencia['Frec Rel'].cumsum()
tabla_frecuencia['Frec Porc Ac'] = tabla_frecuencia['Frec Porc'].cumsum()
print(tabla_frecuencia)
# Out:
#               Clase  Frec  Frec Rel  Frec Porc  Frec Ac  Frec Rel Ac  \
# 4  (17.947, 25.429]    12      0.12       12.0       12         0.12
# 3  (25.429, 32.857]    14      0.14       14.0       26         0.26
# 0  (32.857, 40.286]    18      0.18       18.0       44         0.44
# 2  (40.286, 47.714]    16      0.16       16.0       60         0.60
# 6  (47.714, 55.143]    10      0.10       10.0       70         0.70
# 5  (55.143, 62.571]    12      0.12       12.0       82         0.82
# 1    (62.571, 70.0]    18      0.18       18.0      100         1.00
#
#    Frec Porc Ac
# 4          12.0
# 3          26.0
# 0          44.0
# 2          60.0
# 6          70.0
# 5          82.0
# 1         100.0

# %%
import matplotlib.pyplot as plt #impor
plt.hist(edades, alpha = 0.5)
plt.title("Historama de edades basado en la funcion de matplotlib con valores estandar")
# Out:
# Text(0.5, 1.0, 'Historama de edades basado en la funcion de matplotlib con valores estandar')

# %%
plt.hist(df['Edad'], bins=K, alpha = 0.5)
plt.title("Historama de edades basado en la regla de Struges")
plt.xlabel('Edad')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %% [markdown]
# #Practica 5: Diagrama de Cajas y Bigotes

# %%
edades2 = []

for i in range (100):
  numero_aleatorio = random.randint( 20, 87)
  edades2.append(numero_aleatorio)
print(edades2)
# Out:
# [71, 73, 77, 37, 53, 20, 60, 37, 45, 82, 28, 80, 60, 31, 39, 34, 31, 81, 31, 58, 80, 84, 67, 85, 71, 63, 59, 59, 64, 41, 56, 62, 70, 32, 78, 86, 23, 33, 55, 77, 39, 51, 20, 50, 87, 56, 32, 23, 86, 25, 87, 79, 30, 24, 82, 34, 26, 36, 28, 55, 40, 70, 42, 36, 30, 33, 35, 54, 28, 36, 68, 73, 84, 51, 23, 67, 37, 22, 60, 24, 25, 60, 57, 58, 38, 76, 63, 86, 49, 46, 51, 33, 86, 27, 47, 64, 85, 43, 74, 44]

# %%
fig, (ax1,ax2) = plt.subplots(nrows=1, ncols=2, figsize=(9, 4))
bplot1 = ax1.boxplot(edades, vert=True, patch_artist=True)
ax1.set_title('Edades Encuesta 1')

bplot2 = ax2.boxplot(edades2, vert=True, patch_artist=True)
ax2.set_title('Edades Encuesta 2')
plt.show()

# %%
edades2.append(130)

# %%
fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(9, 4))
bplot1 = ax1.boxplot(edades, vert=True, patch_artist=True)
ax1.set_title('Edades Encuesta 1')

bplot2 = ax2.boxplot(edades2, vert=True, patch_artist=True)
ax2.set_title('Edades Encuesta 2')
plt.show()
